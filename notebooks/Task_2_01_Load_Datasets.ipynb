# %% [markdown]
# ## Step 2: Load a Public Grocery Basket Dataset
#
#
# To train the recommendation model on realistic shopping behaviour, a publicly available grocery transaction dataset is used.
#
# The dataset selected is the UCI "Groceries" dataset, which contains several thousand anonymised shopping baskets. Each transaction represents the set of items purchased together during a single shopping trip.
#
# Due to network restrictions in the local Jupyter environment, the dataset was downloaded manually from a public repository and loaded locally into the notebook.

# %%
# Load required libraries
import pandas as pd

# Load the grocery dataset
file_path = r"C:\coding5final\coding5\data\raw\Groceries_dataset.csv"
df = pd.read_csv(file_path, header=None)

df.head()
# Out:
#                0           1                 2
# 0  Member_number        Date   itemDescription
# 1           1808  21-07-2015    tropical fruit
# 2           2552  05-01-2015        whole milk
# 3           2300  19-09-2015         pip fruit
# 4           1187  12-12-2015  other vegetables
