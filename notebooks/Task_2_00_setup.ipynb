# %% [markdown]
# # Task 2: Recommended Extra Item Model (Market Basket Analysis)
#
# ## Step 1: Problem Definition and Setup
#
# The aim of this task is to build a simple recommendation model that suggests an additional grocery item based on the contents of an existing shopping basket.
#
# This task builds directly on Task 1 by reusing the concept of structured grocery items and shopping baskets, but extends it to multiple customers in order to identify common purchasing patterns.
#
# Rather than predicting individual preference, this model uses co-occurrence relationships between items across many baskets to generate statistically grounded recommendations.

# %%
# %pip install pandas numpy mlxtend
# Out:
# ...
#   Using cached numpy-2.4.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# ...
# Using cached numpy-2.4.1-cp312-cp312-win_amd64.whl (12.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#   Rolling back uninstall of numpy
#   Moving to c:\users\pipki\miniconda3\lib\site-packages\numpy-2.3.4.dist-info\
#    from C:\Users\pipki\miniconda3\Lib\site-packages\~umpy-2.3.4.dist-info
#   Moving to c:\users\pipki\miniconda3\lib\site-packages\numpy.libs\libscipy_openblas64_-860d95b1c38e637ce4509f5fa24fbf2a.dll
#    from C:\Users\pipki\AppData\Local\Temp\pip-uninstall-5paudf24\libscipy_openblas64_-860d95b1c38e637ce4509f5fa24fbf2a.dll
#   Moving to c:\users\pipki\miniconda3\lib\site-packages\numpy.libs\msvcp140-a4c2229bdc2a2a630acdc095b4d86008.dll
#    from C:\Users\pipki\AppData\Local\Temp\pip-uninstall-5paudf24\msvcp140-a4c2229bdc2a2a630acdc095b4d86008.dll
# ...

# %%
# Step 1: Import required libraries

import pandas as pd
import numpy as np

# Libraries for market basket analysis
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
